# %% [markdown]
# #Extracting Frames from video
# This "extract_frame_from_video()" function takes your video path and extract frame from your video and save the extracted frame into frames folder

# %%
import cv2
import os

# %%
def extract_frame_from_video(video_file):
  # Create a directory to store the extracted frames
  if not os.path.exists("frames"):
      os.mkdir("frames")

  # Get the video capture object
  cap = cv2.VideoCapture(video_file)

  # Get the frame rate
  fps = cap.get(cv2.CAP_PROP_FPS)
  print(int(cap.get(cv2.CAP_PROP_FRAME_COUNT)))
  print(fps)
  # Iterate over the frames in the video
  for i in range(int(cap.get(cv2.CAP_PROP_FRAME_COUNT))):
      # Capture the frame
      ret, frame = cap.read()
      frame=cv2.resize(frame,(640,480))

      # Save the frame
      filename = os.path.join("frames", "frame_v%d.png" % i)
      cv2.imwrite(filename, frame)

  # Release the video capture object
  cap.release()
  cv2.destroyAllWindows()

# %%
# Set the video file to be extracted
video_file = "videos/d1.mp4" # your video path
extract_frame_from_video(video_file)

# %% [markdown]
# #Deleting Duplicate Images
#
# This "remove_duplicates images()" function takes your frames folder path, and use hashing technique to find duplicate images and then delete all the duplicate images from folder

# %%
# !pip install imagehash
# Out:
# Collecting imagehash
#   Downloading ImageHash-4.3.1-py2.py3-none-any.whl (296 kB)
#      ------------------------------------ 296.5/296.5 kB 458.1 kB/s eta 0:00:00
# Requirement already satisfied: PyWavelets in c:\users\msi\anaconda3\lib\site-packages (from imagehash) (1.4.1)
# Requirement already satisfied: numpy in c:\users\msi\anaconda3\lib\site-packages (from imagehash) (1.23.5)
# Requirement already satisfied: pillow in c:\users\msi\anaconda3\lib\site-packages (from imagehash) (9.4.0)
# Requirement already satisfied: scipy in c:\users\msi\anaconda3\lib\site-packages (from imagehash) (1.10.0)
# Installing collected packages: imagehash
# Successfully installed imagehash-4.3.1

# %%
import os
from PIL import Image
import imagehash

def get_image_hash(image_path):
    # Open the image and calculate its hash value
    with Image.open(image_path) as img:
        img_hash = imagehash.average_hash(img)
    return img_hash

def remove_duplicate_images(folder_path):
    # Check if the provided folder path is valid
    if not os.path.exists(folder_path):
        print(f"Error: Folder '{folder_path}' does not exist.")
        return

    # Get a list of all files (including images) in the folder
    all_files = os.listdir(folder_path)

    # Filter only the image files (you may adjust the valid image extensions)
    image_files = [file for file in all_files if file.lower().endswith(('.png', '.jpg', '.jpeg', '.gif', '.bmp'))]

    # Check if there are any images in the folder
    if not image_files:
        print(f"No image files found in folder '{folder_path}'.")
        return

    # Create a dictionary to store image hashes and their corresponding filenames
    image_hashes = {}

    # List to store duplicate image filenames
    duplicates_to_delete = []

    try:
        # Iterate through all image files in the folder
        for image in image_files:
            image_path = os.path.join(folder_path, image)
            img_hash = get_image_hash(image_path)

            # Check if the hash value already exists in the dictionary
            if img_hash in image_hashes:
                duplicates_to_delete.append(image)  # Add to duplicate list
            else:
                image_hashes[img_hash] = image  # Add to the dictionary

        # Remove duplicate images
        num_deleted_images = 0
        for duplicate_image in duplicates_to_delete:
            duplicate_image_path = os.path.join(folder_path, duplicate_image)
            os.remove(duplicate_image_path)
            num_deleted_images += 1
            print(f"Removed duplicate image: '{duplicate_image}' from folder '{folder_path}'.")

        print(f"Total {num_deleted_images} duplicate images deleted.")

    except Exception as e:
        print(f"Error occurred while removing duplicate images: {e}")

# %%
# put your fraes folder path
folder_path = "D:/renamed"
remove_duplicate_images(folder_path)

# %% [markdown]
# # Anonating Images
#
# After frame extraction and remove duplicate images. We need to do annotating the images.
#
# For image annotating I use labelImg tool. It is a open source(free) tool for labeling the image. you an download labelImg from the github repository link :-  https://github.com/HumanSignal/labelImg
#
# 1. clone this repo
# 2. run labelImg.py file in your anaconda prompt
# 3. label images in PascalVOC format

# %%
import os
from glob import glob
import pandas as pd
from functools import reduce
from xml.etree import ElementTree as
#  'D:/Labelled/Data_1\\image_793.xml',
#  'D:/Labelled/Data_1\\image_794.xml',
#  'D:/Labelled/Data_1\\image_795.xml',
#  'D:/Labelled/Data_1\\image_80.xml',
#  'D:/Labelled/Data_1\\image_81.xml',
#  'D:/Labelled/Data_1\\image_82.xml',
#  'D:/Labelled/Data_1\\image_83.xml',
#  'D:/Labelled/Data_1\\image_84.xml',
#  'D:/Labelled/Data_1\\image_85.xml',
#  'D:/Labelled/Data_1\\image_86.xml',
#  'D:/Labelled/Data_1\\image_87.xml',
#  'D:/Labelled/Data_1\\image_88.xml',
#  'D:/Labelled/Data_1\\image_89.xml',
#  'D:/Labelled/Data_1\\image_9.xml',
#  'D:/Labelled/Data_1\\image_90.xml',
#  'D:/Labelled/Data_1\\image_91.xml',
#  'D:/Labelled/Data_1\\image_94.xml',
#  'D:/Labelled/Data_1\\image_97.xml',
#  'D:/Labelled/Data_1\\image_99.xml']

# %%
# replacing \\ to /

xml_list = list(map(lambda x : x.replace('\\', '/'), xml_list))

# %%
# Reading all xml file
# From each XML file we need extract
# filename, size(width, heigth), object(name, xmin, xmax, ymin, ymax)

def extract_text_from_xml(filename):
    tree = et.parse(filename)
    root = tree.getroot()

    # extract file name
    image_name = root.find('filename').text

    # extract dimension of image
    image_width = root.find('size').find('width').text
    image_height = root.find('size').find('height').text

    parser = []
    # extract name, xmin, xmax, ymin, ymax
    for obj in root.findall('object'):
        obj_name = obj.find('name').text
        xmin = obj.find('bndbox').find('xmin').text
        xmax = obj.find('bndbox').find('xmax').text
        ymin = obj.find('bndbox').find('ymin').text
        ymax = obj.find('bndbox').find('ymax').text
        parser.append([image_name, image_width, image_height, obj_name, xmin, xmax, ymin, ymax])

    return parser

# %%
parser = list(map(extract_text_from_xml, xml_list))

# %%
# reducind data dimension 3D to 2D
data = reduce(lambda x, y : x+y, parser)

# %%
data
# Out:
# [['image_0.jpg', '338', '339', 'car', '71', '267', '107', '278'],
#  ['image_1.jpg', '670', '600', 'car', '2', '670', '65', '532'],
#  ['image_100.jpg', '187', '240', 'car', '21', '127', '141', '236'],
#  ['image_103.jpg', '500', '280', 'car', '11', '496', '18', '265'],
#  ['image_104.jpg', '320', '224', 'car', '13', '299', '61', '150'],
#  ['image_105.jpg', '320', '213', 'car', '26', '313', '81', '198'],
#  ['image_106.jpg', '319', '213', 'car', '12', '301', '79', '185'],
#  ['image_108.jpg', '360', '240', 'car', '45', '309', '57', '186'],
#  ['image_11.jpg', '320', '240', 'car', '9', '155', '86', '188'],
#  ['image_11.jpg', '320', '240', 'car', '160', '313', '83', '177'],
#  ['image_113.jpg', '320', '214', 'car', '12', '293', '32', '198'],
#  ['image_114.jpg', '240', '180', 'car', '49', '189', '19', '152'],
#  ['image_116.jpg', '1280', '853', 'car', '251', '932', '262', '615'],
#  ['image_118.jpg', '400', '225', 'car', '55', '317', '25', '176'],
#  ['image_119.jpg', '319', '213', 'car', '19', '285', '46', '202'],
#  ['image_12.jpg', '320', '240', 'person', '21', '34', '78', '114'],
#  ['image_12.jpg', '320', '240', 'person', '151', '161', '79', '106'],
#  ['image_12.jpg', '320', '240', 'person', '163', '167', '78', '107'],
#  ['image_12.jpg', '320', '240', 'car', '125', '318', '107', '186'],
#  ['image_123.jpg', '320', '215', 'car', '12', '314', '11', '210'],
#  ['image_124.jpg', '500', '183', 'car', '3', '500', '1', '157'],
#  ['image_128.jpg', '399', '216', 'car', '72', '226', '131', '192'],
#  ['image_13.jpg', '500', '222', 'car', '6', '486', '2', '217'],
#  ['image_133.jpg', '820', '337', 'car', '135', '694', '37', '300'],
#  ['image_134.jpg', '320', '216', 'car', '15', '302', '59', '174'],
#  ['image_135.jpg', '820', '387', 'car', '187', '638', '53', '319'],
#  ['image_136.jpg', '320', '212', 'car', '8', '316', '15', '193'],
#  ['image_137.jpg', '1024', '768', 'car', '75', '987', '124', '688'],
#  ['image_138.jpg', '319', '205', 'car', '12', '290', '2', '202'],
#  ['image_139.jpg', '399', '225', 'car', '48', '378', '50', '207'],
#  ['image_14.jpg', '320', '240', 'car', '1', '316', '113', '208'],
#  ['image_140.jpg', '320', '240', 'car', '9', '306', '53', '179'],
#  ['image_141.jpg', '180', '240', 'car', '5', '180', '73', '193'],
#  ['image_142.jpg', '320', '212', 'car', '16', '189', '59', '159'],
#  ['image_144.jpg', '860', '356', 'car', '164', '697', '46', '336'],
#  ['image_145.jpg', '3506', '1972', 'car', '632', '2709', '595', '1450'],
#  ['image_149.jpg', '319', '213', 'car', '17', '314', '95', '188'],
#  ['image_15.jpg', '320', '240', 'car', '21', '292', '35', '205'],
#  ['image_150.jpg', '320', '240', 'car', '39', '270', '44', '200'],
#  ['image_151.jpg', '320', '240', 'car', '19', '305', '36', '213'],
#  ['image_153.jpg', '320', '240', 'car', '17', '312', '42', '212'],
#  ['image_154.jpg', '320', '240', 'car', '56', '318', '31', '210'],
#  ['image_156.jpg', '1920', '1080', 'car', '594', '1572', '359', '949'],
#  ['image_157.jpg', '1024', '768', 'car', '422', '965', '120', '610'],
#  ['image_158.jpg', '1920', '1200', 'car', '318', '1614', '162', '1056'],
#  ['image_159.jpg', '1920', '1080', 'car', '347', '1687', '155', '959'],
#  ['image_160.jpg', '320', '240', 'car', '38', '259', '78', '166'],
#  ['image_164.jpg', '320', '230', 'car', '56', '258', '80', '194'],
#  ['image_166.jpg', '320', '240', 'car', '62', '235', '89', '178'],
#  ['image_166.jpg', '320', '240', 'person', '16', '35', '88', '131'],
#  ['image_166.jpg', '320', '240', 'person', '295', '320', '79', '144'],
#  ['image_167.jpg', '400', '225', 'car', '9', '269', '78', '181'],
#  ['image_170.jpg', '728', '406', 'car', '112', '657', '8', '355'],
#  ['image_171.jpg', '1600', '900', 'car', '4', '523', '85', '369'],
#  ['image_171.jpg', '1600', '900', 'car', '547', '1041', '86', '384'],
#  ['image_171.jpg', '1600', '900', 'car', '1063', '1540', '59', '385'],
#  ['image_171.jpg', '1600', '900', 'car', '21', '624', '481', '819'],
#  ['image_171.jpg', '1600', '900', 'car', '634', '1024', '459', '784'],
#  ['image_171.jpg', '1600', '900', 'car', '1035', '1579', '455', '821'],
#  ['image_172.jpg', '1599', '900', 'car', '30', '1533', '238', '864'],
#  ['image_174.jpg', '320', '240', 'car', '17', '315', '84', '201'],
#  ['image_176.jpg', '240', '192', 'car', '17', '194', '49', '150'],
#  ['image_184.jpg', '320', '214', 'car', '17', '312', '77', '201'],
#  ['image_186.jpg', '320', '213', 'car', '20', '259', '38', '188'],
#  ['image_188.jpg', '320', '214', 'car', '30', '302', '32', '192'],
#  ['image_19.jpg', '320', '240', 'car', '12', '312', '59', '197'],
#  ['image_193.jpg', '320', '240', 'car', '63', '272', '66', '148'],
#  ['image_195.jpg', '240', '199', 'car', '1', '239', '38', '184'],
#  ['image_196.jpg', '320', '240', 'car', '12', '308', '77', '224'],
#  ['image_197.jpg', '320', '230', 'car', '23', '303', '56', '189'],
#  ['image_198.jpg', '320', '240', 'car', '24', '303', '47', '183'],
#  ['image_2.jpg', '2000', '1333', 'car', '393', '1665', '368', '946'],
#  ['image_20.jpg', '1600', '900', 'car', '337', '1251', '61', '806'],
#  ['image_200.jpg', '320', '211', 'car', '29', '295', '77', '183'],
#  ['image_200.jpg', '320', '211', 'person', '115', '140', '39', '75'],
#  ['image_200.jpg', '320', '211', 'person', '211', '231', '39', '76'],
#  ['image_201.jpg', '320', '225', 'car', '20', '294', '65', '181'],
#  ['image_202.jpg', '320', '240', 'car', '11', '320', '31', '224'],
#  ['image_205.jpg', '320', '240', 'car', '41', '298', '58', '198'],
#  ['image_207.jpg', '320', '240', 'car', '13', '318', '13', '240'],
#  ['image_208.jpg', '320', '240', 'car', '31', '288', '16', '218'],
#  ['image_211.jpg', '320', '213', 'car', '4', '318', '35', '174'],
#  ['image_214.jpg', '320', '180', 'car', '7', '308', '6', '158'],
#  ['image_215.jpg', '320', '240', 'car', '75', '297', '45', '208'],
#  ['image_217.jpg', '1920', '1080', 'car', '664', '1890', '330', '984'],
#  ['image_218.jpg', '320', '240', 'car', '17', '306', '33', '225'],
#  ['image_219.jpg', '320', '213', 'car', '5', '318', '3', '213'],
#  ['image_220.jpg', '728', '426', 'car', '86', '651', '35', '400'],
#  ['image_221.jpg', '890', '501', 'car', '73', '795', '133', '461'],
#  ['image_225.jpg', '860', '609', 'car', '39', '833', '24', '555'],
#  ['image_229.jpg', '320', '240', 'car', '21', '296', '50', '205'],
#  ['image_230.jpg', '320', '240', 'car', '35', '306', '46', '192'],
#  ['image_231.jpg', '320', '240', 'car', '39', '306', '45', '203'],
#  ['image_235.jpg', '319', '213', 'person', '53', '236', '12', '195'],
#  ['image_239.jpg', '319', '213', 'car', '122', '236', '87', '157'],
#  ['image_240.jpg', '320', '199', 'car', '9', '320', '57', '167'],
#  ['image_241.jpg', '320', '222', 'car', '14', '222', '88', '202'],
#  ['image_242.jpg', '319', '195', 'car', '17', '319', '14', '184'],
#  ['image_244.jpg', '320', '240', 'car', '8', '306', '55', '192'],
#  ['image_249.jpg', '320', '180', 'car', '64', '266', '31', '138'],
#  ['image_250.jpg', '320', '240', 'car', '16', '301', '53', '166'],
#  ['image_256.jpg', '280', '280', 'car', '8', '280', '65', '201'],
#  ['image_260.jpg', '860', '644', 'car', '80', '826', '29', '549'],
#  ['image_268.jpg', '500', '542', 'car', '7', '500', '195', '431'],
#  ['image_271.jpg', '1000', '600', 'car', '192', '767', '144', '534'],
#  ['image_274.jpg', '1680', '756', 'car', '468', '1573', '176', '673'],
#  ['image_284.jpg', '180', '240', 'car', '3', '180', '18', '197'],
#  ['image_286.jpg', '320', '239', 'car', '10', '315', '23', '233'],
#  ['image_299.jpg', '480', '480', 'car', '12', '469', '168', '367'],
#  ['image_310.jpg', '320', '240', 'car', '7', '320', '35', '240'],
#  ['image_317.jpg', '1280', '720', 'car', '122', '1156', '215', '631'],
#  ['image_32.jpg', '319', '213', 'car', '44', '258', '53', '193'],
#  ['image_323.jpg', '569', '569', 'car', '8', '569', '121', '438'],
#  ['image_325.jpg', '400', '211', 'car', '129', '335', '80', '185'],
#  ['image_33.jpg', '240', '180', 'car', '2', '237', '49', '180'],
#  ['image_332.jpg', '320', '216', 'car', '32', '320', '60', '205'],
#  ['image_333.jpg', '320', '213', 'car', '38', '288', '12', '202'],
#  ['image_34.jpg', '320', '240', 'car', '63', '272', '52', '147'],
#  ['image_344.jpg', '320', '245', 'car', '6', '317', '14', '237'],
#  ['image_348.jpg', '660', '450', 'car', '61', '565', '148', '370'],
#  ['image_35.jpg', '320', '213', 'car', '38', '292', '70', '187'],
#  ['image_355.jpg', '319', '213', 'car', '93', '266', '36', '156'],
#  ['image_356.jpg', '319', '213', 'car', '2', '264', '49', '175'],
#  ['image_36.jpg', '320', '213', 'car', '39', '283', '56', '178'],
#  ['image_36.jpg', '320', '213', 'person', '287', '315', '52', '136'],
#  ['image_367.jpg', '1024', '768', 'car', '179', '882', '337', '648'],
#  ['image_368.jpg', '3840', '2160', 'car', '584', '2936', '516', '1877'],
#  ['image_369.jpg', '1024', '768', 'car', '59', '841', '187', '702'],
#  ['image_370.jpg', '4000', '1705', 'car', '554', '3273', '235', '1491'],
#  ['image_371.jpg', '3000', '2000', 'car', '160', '1826', '946', '1829'],
#  ['image_383.jpg', '728', '431', 'car', '20', '712', '18', '421'],
#  ['image_385.jpg', '1600', '900', 'car', '410', '1242', '304', '810'],
#  ['image_387.jpg', '1300', '955', 'car', '75', '1241', '94', '791'],
#  ['image_389.jpg', '1280', '720', 'car', '144', '1199', '31', '714'],
#  ['image_39.jpg', '320', '212', 'person', '69', '258', '38', '200'],
#  ['image_390.jpg', '2160', '1440', 'car', '134', '2014', '39', '1393'],
#  ['image_391.jpg', '1600', '900', 'car', '174', '1334', '118', '900'],
#  ['image_392.jpg', '1372', '772', 'car', '78', '1289', '150', '662'],
#  ['image_393.jpg', '600', '399', 'car', '32', '586', '74', '329'],
#  ['image_394.jpg', '1600', '1066', 'car', '291', '1370', '322', '804'],
#  ['image_395.jpg', '1250', '750', 'car', '110', '1243', '166', '633'],
#  ['image_396.jpg', '1200', '800', 'car', '253', '1032', '238', '615'],
#  ['image_397.jpg', '1280', '720', 'car', '259', '1005', '54', '648'],
#  ['image_398.jpg', '1280', '720', 'car', '89', '1182', '174', '611'],
#  ['image_4.jpg', '320', '240', 'car', '20', '316', '56', '235'],
#  ['image_400.jpg', '1200', '900', 'car', '11', '1131', '77', '850'],
#  ['image_402.jpg', '2400', '1600', 'car', '287', '2095', '520', '1243'],
#  ['image_403.jpg', '1200', '900', 'person', '14', '222', '21', '848'],
#  ['image_403.jpg', '1200', '900', 'car', '233', '1072', '130', '852'],
#  ['image_404.jpg', '1680', '756', 'car', '648', '1269', '213', '655'],
#  ['image_405.jpg', '1600', '1600', 'car', '217', '1456', '408', '1184'],
#  ['image_406.jpg', '890', '501', 'car', '49', '840', '125', '405'],
#  ['image_407.jpg', '1200', '675', 'car', '37', '535', '81', '305'],
#  ['image_408.jpg', '360', '240', 'car', '42', '314', '61', '191'],
#  ['image_409.jpg', '1445', '813', 'car', '198', '1293', '110', '668'],
#  ['image_41.jpg', '319', '213', 'car', '57', '305', '48', '182'],
#  ['image_410.jpg', '750', '450', 'car', '37', '723', '55', '383'],
#  ['image_411.jpg', '1545', '869', 'car', '278', '1286', '114', '768'],
#  ['image_412.jpg', '1400', '787', 'car', '137', '1283', '143', '687'],
#  ['image_43.jpg', '320', '240', 'car', '9', '319', '90', '189'],
#  ['image_44.jpg', '192', '240', 'car', '30', '163', '102', '184'],
#  ['image_45.jpg', '320', '240', 'car', '15', '311', '58', '168'],
#  ['image_46.jpg', '400', '225', 'car', '124', '372', '33', '190'],
#  ['image_47.jpg', '136', '240', 'car', '16', '124', '132', '216'],
#  ['image_48.jpg', '320', '212', 'car', '3', '293', '10', '181'],
#  ['image_49.jpg', '180', '240', 'person', '38', '56', '54', '96'],
#  ['image_50.jpg', '320', '214', 'car', '92', '187', '80', '138'],
#  ['image_51.jpg', '320', '240', 'car', '5', '133', '94', '162'],
#  ['image_51.jpg', '320', '240', 'car', '137', '219', '92', '149'],
#  ['image_52.jpg', '320', '214', 'car', '2', '309', '55', '148'],
#  ['image_53.jpg', '1200', '800', 'car', '279', '999', '217', '753'],
#  ['image_54.jpg', '240', '180', 'car', '26', '207', '82', '171'],
#  ['image_54.jpg', '240', '180', 'person', '211', '235', '72', '133'],
#  ['image_55.jpg', '400', '216', 'car', '72', '280', '27', '155'],
#  ['image_56.jpg', '319', '213', 'car', '24', '269', '48', '177'],
#  ['image_57.jpg', '400', '225', 'car', '57', '291', '92', '225'],
#  ['image_58.jpg', '320', '240', 'car', '21', '290', '78', '161'],
#  ['image_59.jpg', '319', '179', 'car', '86', '220', '87', '163'],
#  ['image_6.jpg', '319', '213', 'car', '2', '297', '49', '176'],
#  ['image_60.jpg', '319', '213', 'car', '25', '283', '40', '187'],
#  ['image_61.jpg', '320', '240', 'car', '3', '308', '58', '194'],
#  ['image_62.jpg', '1680', '756', 'car', '686', '1641', '215', '636'],
#  ['image_63.jpg', '1280', '720', 'car', '7', '1269', '70', '684'],
#  ['image_66.jpg', '319', '196', 'car', '27', '311', '49', '170'],
#  ['image_67.jpg', '319', '213', 'car', '25', '281', '45', '188'],
#  ['image_68.jpg', '320', '240', 'car', '1', '310', '11', '193'],
#  ['image_69.jpg', '500', '280', 'car', '36', '466', '48', '242'],
#  ['image_70.jpg', '500', '280', 'car', '6', '91', '138', '204'],
#  ['image_70.jpg', '500', '280', 'car', '97', '190', '150', '204'],
#  ['image_70.jpg', '500', '280', 'car', '196', '312', '129', '219'],
#  ['image_70.jpg', '500', '280', 'car', '316', '409', '140', '209'],
#  ['image_70.jpg', '500', '280', 'car', '416', '492', '135', '206'],
#  ['image_71.jpg', '500', '280', 'car', '8', '112', '71', '154'],
#  ['image_71.jpg', '500', '280', 'car', '114', '273', '126', '222'],
#  ['image_71.jpg', '500', '280', 'car', '278', '434', '125', '213'],
#  ['image_72.jpg', '500', '280', 'car', '3', '435', '40', '261'],
#  ['image_724.jpg', '2000', '3000', 'person', '211', '2000', '615', '2986'],
#  ['image_725.jpg', '2000', '3000', 'person', '766', '1376', '244', '2009'],
#  ['image_726.jpg', '2000', '1333', 'person', '907', '1104', '294', '895'],
#  ['image_728.jpg', '2000', '1333', 'person', '263', '1744', '37', '1333'],
#  ['image_729.jpg', '2000', '3000', 'person', '163', '2000', '105', '3000'],
#  ['image_73.jpg', '500', '280', 'car', '9', '493', '10', '251'],
#  ['image_730.jpg', '2000', '1500', 'person', '6', '2000', '10', '1500'],
#  ['image_731.jpg', '2000', '1333', 'person', '885', '1106', '732', '1129'],
#  ['image_732.jpg', '2000', '1333', 'person', '393', '1508', '330', '1175'],
#  ['image_733.jpg', '2000', '3000', 'person', '47', '2000', '193', '3000'],
#  ['image_734.jpg', '2000', '1333', 'person', '313', '1444', '194', '1329'],
#  ['image_736.jpg', '2000', '1376', 'person', '803', '1216', '530', '1246'],
#  ['image_74.jpg', '500', '280', 'car', '20', '483', '17', '247'],
#  ['image_741.jpg', '2000', '1333', 'person', '811', '1182', '321', '1299'],
#  ['image_743.jpg', '2000', '1333', 'person', '537', '1500', '106', '1333'],
#  ['image_744.jpg', '2000', '1329', 'person', '1113', '1320', '533', '978'],
#  ['image_745.jpg', '2000', '1333', 'person', '1087', '1411', '474', '1163'],
#  ['image_747.jpg', '2000', '1333', 'person', '479', '1500', '292', '1333'],
#  ['image_749.jpg', '2000', '3000', 'person', '889', '1547', '818', '2809'],
#  ['image_752.jpg', '2000', '1333', 'person', '565', '1480', '130', '1333'],
#  ['image_753.jpg', '2000', '1335', 'person', '1131', '1816', '188', '1272'],
#  ['image_754.jpg', '2000', '1333', 'person', '987', '1165', '497', '902'],
#  ['image_755.jpg', '2000', '1333', 'person', '724', '1786', '36', '1333'],
#  ['image_756.jpg', '2000', '1375', 'person', '803', '1170', '324', '959'],
#  ['image_757.jpg', '2000', '1333', 'person', '451', '762', '426', '1156'],
#  ['image_758.jpg', '2000', '1333', 'person', '338', '1535', '9', '1332'],
#  ['image_759.jpg', '2000', '2997', 'person', '240', '1669', '1095', '2966'],
#  ['image_76.jpg', '240', '156', 'car', '9', '230', '23', '141'],
#  ['image_760.jpg', '2000', '1333', 'person', '556', '1430', '366', '1328'],
#  ['image_761.jpg', '2000', '1334', 'person', '649', '1296', '322', '1334'],
#  ['image_762.jpg', '2000', '1281', 'person', '991', '1157', '675', '1109'],
#  ['image_763.jpg', '2000', '2000', 'person', '221', '1647', '323', '2000'],
#  ['image_764.jpg', '2000', '1953', 'person', '128', '1913', '228', '1953'],
#  ['image_765.jpg', '2000', '1333', 'person', '845', '1220', '205', '1013'],
#  ['image_769.jpg', '2000', '3000', 'person', '801', '1466', '618', '2999'],
#  ['image_77.jpg', '1920', '931', 'car', '172', '928', '184', '692'],
#  ['image_770.jpg', '2000', '2500', 'person', '690', '1401', '957', '2400'],
#  ['image_771.jpg', '1727', '2591', 'person', '36', '1727', '142', '2591'],
#  ['image_772.jpg', '2000', '3000', 'person', '85', '2000', '199', '2989'],
#  ['image_773.jpg', '2000', '1333', 'person', '749', '1265', '305', '1308'],
#  ['image_774.jpg', '2000', '1333', 'person', '797', '1155', '509', '1166'],
#  ['image_777.jpg', '2000', '3001', 'person', '140', '2000', '145', '3001'],
#  ['image_778.jpg', '2000', '1333', 'person', '921', '1063', '843', '1094'],
#  ['image_779.jpg', '2000', '1333', 'person', '358', '717', '299', '850'],
#  ['image_78.jpg', '320', '240', 'car', '6', '308', '29', '221'],
#  ['image_780.jpg', '2000', '1333', 'person', '904', '1121', '668', '1147'],
#  ['image_781.jpg', '2000', '1333', 'person', '961', '1273', '404', '797'],
#  ['image_782.jpg', '2000', '3000', 'person', '105', '1882', '544', '3000'],
#  ['image_783.jpg', '2000', '1369', 'person', '589', '1389', '262', '1367'],
#  ['image_784.jpg', '2000', '3026', 'person', '750', '1156', '1160', '1786'],
#  ['image_785.jpg', '2000', '1333', 'person', '462', '1031', '360', '1043'],
#  ['image_786.jpg', '2000', '3000', 'person', '69', '1985', '83', '2976'],
#  ['image_787.jpg', '2000', '1354', 'person', '618', '1421', '293', '1354'],
#  ['image_788.jpg', '2000', '1335', 'person', '666', '1286', '257', '1335'],
#  ['image_789.jpg', '2000', '3000', 'person', '72', '1930', '331', '2996'],
#  ['image_79.jpg', '1920', '1080', 'car', '206', '1391', '294', '895'],
#  ['image_790.jpg', '2000', '1333', 'person', '679', '994', '375', '1244'],
#  ['image_791.jpg', '2000', '3000', 'person', '827', '1214', '1670', '2564'],
#  ['image_792.jpg', '2000', '3000', 'person', '518', '1414', '302', '2612'],
#  ['image_793.jpg', '2000', '2500', 'person', '1358', '1695', '927', '1409'],
#  ['image_794.jpg', '2000', '1333', 'person', '847', '1259', '212', '1157'],
#  ['image_795.jpg', '2000', '1500', 'person', '171', '1108', '102', '1273'],
#  ['image_80.jpg', '320', '240', 'car', '16', '281', '53', '211'],
#  ['image_81.jpg', '1920', '1200', 'car', '401', '1494', '330', '909'],
#  ['image_82.jpg', '860', '703', 'car', '36', '841', '23', '645'],
#  ['image_83.jpg', '240', '180', 'car', '15', '230', '6', '166'],
#  ['image_84.jpg', '1024', '768', 'car', '177', '887', '136', '636'],
#  ['image_85.jpg', '1600', '794', 'car', '60', '1528', '20', '789'],
#  ['image_86.jpg', '1200', '900', 'car', '146', '1068', '194', '750'],
#  ['image_87.jpg', '1970', '1231', 'car', '163', '1959', '50', '1208'],
#  ['image_88.jpg', '1920', '1080', 'car', '143', '1736', '183', '1049'],
#  ['image_89.jpg', '680', '451', 'car', '100', '571', '131', '384'],
#  ['image_9.jpg', '240', '180', 'car', '3', '236', '26', '167'],
#  ['image_90.jpg', '872', '578', 'car', '62', '833', '110', '539'],
#  ['image_91.jpg', '2560', '1440', 'car', '471', '2171', '470', '1209'],
#  ['image_94.jpg', '1600', '900', 'car', '69', '1532', '105', '870'],
#  ['image_97.jpg', '319', '213', 'car', '29', '264', '76', '203'],
#  ['image_99.jpg', '1024', '683', 'car', '124', '911', '159', '574']]

# %% [markdown]
# ### creating Pandas Dataframe to store above rsults

# %%
df = pd.DataFrame(data, columns = ['image_name', 'image_width', 'image_height', 'obj_name', 'xmin', 'xmax', 'ymin', 'ymax'])

# %%
df
# Out:
#         image_name image_width image_height obj_name xmin  xmax ymin  ymax
# 0      image_0.jpg         338          339      car   71   267  107   278
# 1      image_1.jpg         670          600      car    2   670   65   532
# 2    image_100.jpg         187          240      car   21   127  141   236
# 3    image_103.jpg         500          280      car   11   496   18   265
# 4    image_104.jpg         320          224      car   13   299   61   150
# ..             ...         ...          ...      ...  ...   ...  ...   ...
# 269   image_90.jpg         872          578      car   62   833  110   539
# 270   image_91.jpg        2560         1440      car  471  2171  470  1209
# 271   image_94.jpg        1600          900      car   69  1532  105   870
# 272   image_97.jpg         319          213      car   29   264   76   203
# 273   image_99.jpg        1024          683      car  124   911  159   574
#
# [274 rows x 8 columns]

# %%
df.shape
# Out:
# (274, 8)

# %%
df['image_name'].value_counts()
# Out:
# image_171.jpg    6
# image_70.jpg     5
# image_12.jpg     4
# image_166.jpg    3
# image_200.jpg    3
#                 ..
# image_271.jpg    1
# image_274.jpg    1
# image_284.jpg    1
# image_286.jpg    1
# image_99.jpg     1
# Name: image_name, Length: 251, dtype: int64

# %%
df['obj_name'].value_counts()
# Out:
# car       205
# person     69
# Name: obj_name, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 274 entries, 0 to 273
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   image_name    274 non-null    object
#  1   image_width   274 non-null    object
#  2   image_height  274 non-null    object
#  3   obj_name      274 non-null    object
#  4   xmin          274 non-null    object
#  5   xmax          274 non-null    object
#  6   ymin          274 non-null    object
#  7   ymax          274 non-null    object
# dtypes: object(8)
# memory usage: 17.2+ KB

# %%
# converting object datatype to int
column = ['image_width', 'image_height', 'xmin', 'xmax', 'ymin', 'ymax']
df[column] = df[column].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 274 entries, 0 to 273
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   image_name    274 non-null    object
#  1   image_width   274 non-null    int32
#  2   image_height  274 non-null    int32
#  3   obj_name      274 non-null    object
#  4   xmin          274 non-null    int32
#  5   xmax          274 non-null    int32
#  6   ymin          274 non-null    int32
#  7   ymax          274 non-null    int32
# dtypes: int32(6), object(2)
# memory usage: 10.8+ KB

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['label'] = le.fit_transform(df['obj_name'])

# %%
# calculating center_x, center_y, width and height for yolo format

df['center_x'] = ((df['xmin'] + df['xmax'])/2)/df['image_width']
df['center_y'] = ((df['ymin'] + df['ymax'])/2)/df['image_height']

df['weidth'] = (df['xmax'] - df['xmin'])/df['image_width']
df['height'] = (df['ymax'] - df['ymin'])/df['image_height']

# %%
df.head(60)
# Out:
#        image_name  image_width  image_height obj_name  xmin  xmax  ymin  ymax  \
# 0     image_0.jpg          338           339      car    71   267   107   278
# 1     image_1.jpg          670           600      car     2   670    65   532
# 2   image_100.jpg          187           240      car    21   127   141   236
# 3   image_103.jpg          500           280      car    11   496    18   265
# 4   image_104.jpg          320           224      car    13   299    61   150
# 5   image_105.jpg          320           213      car    26   313    81   198
# 6   image_106.jpg          319           213      car    12   301    79   185
# 7   image_108.jpg          360           240      car    45   309    57   186
# 8    image_11.jpg          320           240      car     9   155    86   188
# 9    image_11.jpg          320           240      car   160   313    83   177
# 10  image_113.jpg          320           214      car    12   293    32   198
# 11  image_114.jpg          240           180      car    49   189    19   152
# 12  image_116.jpg         1280           853      car   251   932   262   615
# 13  image_118.jpg          400           225      car    55   317    25   176
# 14  image_119.jpg          319           213      car    19   285    46   202
# 15   image_12.jpg          320           240   person    21    34    78   114
# 16   image_12.jpg          320           240   person   151   161    79   106
# 17   image_12.jpg          320           240   person   163   167    78   107
# 18   image_12.jpg          320           240      car   125   318   107   186
# 19  image_123.jpg          320           215      car    12   314    11   210
# 20  image_124.jpg          500           183      car     3   500     1   157
# 21  image_128.jpg          399           216      car    72   226   131   192
# 22   image_13.jpg          500           222      car     6   486     2   217
# 23  image_133.jpg          820           337      car   135   694    37   300
# 24  image_134.jpg          320           216      car    15   302    59   174
# 25  image_135.jpg          820           387      car   187   638    53   319
# 26  image_136.jpg          320           212      car     8   316    15   193
# 27  image_137.jpg         1024           768      car    75   987   124   688
# 28  image_138.jpg          319           205      car    12   290     2   202
# 29  image_139.jpg          399           225      car    48   378    50   207
# 30   image_14.jpg          320           240      car     1   316   113   208
# 31  image_140.jpg          320           240      car     9   306    53   179
# 32  image_141.jpg          180           240      car     5   180    73   193
# 33  image_142.jpg          320           212      car    16   189    59   159
# 34  image_144.jpg          860           356      car   164   697    46   336
# 35  image_145.jpg         3506          1972      car   632  2709   595  1450
# 36  image_149.jpg          319           213      car    17   314    95   188
# 37   image_15.jpg          320           240      car    21   292    35   205
# 38  image_150.jpg          320           240      car    39   270    44   200
# 39  image_151.jpg          320           240      car    19   305    36   213
# 40  image_153.jpg          320           240      car    17   312    42   212
# 41  image_154.jpg          320           240      car    56   318    31   210
# 42  image_156.jpg         1920          1080      car   594  1572   359   949
# 43  image_157.jpg         1024           768      car   422   965   120   610
# 44  image_158.jpg         1920          1200      car   318  1614   162  1056
# 45  image_159.jpg         1920          1080      car   347  1687   155   959
# 43      0  0.677246  0.475260  0.530273  0.638021
# 44      0  0.503125  0.507500  0.675000  0.745000
# 45      0  0.529687  0.515741  0.697917  0.744444
# 46      0  0.464062  0.508333  0.690625  0.366667
# 47      0  0.490625  0.595652  0.631250  0.495652
# 48      0  0.464062  0.556250  0.540625  0.370833
# 49      1  0.079687  0.456250  0.059375  0.179167
# 50      1  0.960938  0.464583  0.078125  0.270833
# 51      0  0.347500  0.575556  0.650000  0.457778
# 52      0  0.528159  0.447044  0.748626  0.854680
# 53      0  0.164687  0.252222  0.324375  0.315556
# 54      0  0.496250  0.261111  0.308750  0.331111
# 55      0  0.813438  0.246667  0.298125  0.362222
# 56      0  0.201563  0.722222  0.376875  0.375556
# 57      0  0.518125  0.690556  0.243750  0.361111
# 58      0  0.816875  0.708889  0.340000  0.406667
# 59      0  0.488743  0.612222  0.939962  0.695556

# %%
# train test split

images = df['image_name'].unique()

img_df = pd.DataFrame(images, columns=['image_name'])

# select 80% random images
img_train = tuple(img_df.sample(frac = 0.8)['image_name'])

# %%
# train
img_df
# Out:
#         image_name
# 0      image_0.jpg
# 1      image_1.jpg
# 2    image_100.jpg
# 3    image_103.jpg
# 4    image_104.jpg
# ..             ...
# 246   image_90.jpg
# 247   image_91.jpg
# 248   image_94.jpg
# 249   image_97.jpg
# 250   image_99.jpg
#
# [251 rows x 1 columns]

# %%
img_test = tuple(img_df.query(f'image_name not in {img_train}')['image_name'])

# %%
# saving training and testing image in folder with there respective txt files

from shutil import move

# %%
train_df = df.query(f'image_name in {img_train}')
test_df = df.query(f'image_name in {img_test}')

# %%
train_folder = 'D:/Labelled/Data_1/data/train'
test_folder = 'D:/Labelled/Data_1/data/test'

# creating folder
os.makedirs(train_folder)
os.makedirs(test_folder)

# %%
column = ['image_name', 'label', 'center_x', 'center_y', 'weidth', 'height']

grouped_train_df = train_df[column].groupby('image_name')

grouped_test_df = test_df[column].groupby('image_name')

# %%
grouped_train_df.head(50)
# Out:
#         image_name  label  center_x  center_y    weidth    height
# 0      image_0.jpg      1  0.500000  0.567847  0.579882  0.504425
# 1      image_1.jpg      1  0.501493  0.497500  0.997015  0.778333
# 2    image_100.jpg      1  0.395722  0.785417  0.566845  0.395833
# 3    image_103.jpg      1  0.507000  0.505357  0.970000  0.882143
# 4    image_104.jpg      1  0.487500  0.470982  0.893750  0.397321
# ..             ...    ...       ...       ...       ...       ...
# 269   image_90.jpg      1  0.513188  0.561419  0.884174  0.742215
# 270   image_91.jpg      1  0.516016  0.582986  0.664062  0.513194
# 271   image_94.jpg      1  0.500313  0.541667  0.914375  0.850000
# 272   image_97.jpg      1  0.459248  0.654930  0.736677  0.596244
# 273   image_99.jpg      1  0.505371  0.536603  0.768555  0.607613
#
# [221 rows x 6 columns]

# %%
# grouped_train_df.get_group('image_94.jpg').set_index('image_name').to_csv('sample.txt', index=False, header=False)

# %%
# this function create .txt file for each unique image and save it to destination folder with image

def save_data(image_name, folder_path, grouped_obj):
    src_path = os.path.join('D:/Labelled/Data_1/', image_name)
    dst_path = os.path.join(folder_path, image_name)
    print(src_path," ",dst_path)
    move(src_path, dst_path)

    # saving anotation in .txt file
    text_filename = os.path.join(folder_path , os.path.splitext(image_name)[0] + '.txt')
    grouped_obj.get_group(image_name).set_index('image_name').to_csv(text_filename, sep=' ', index=False, header=False)

# %%
# save_data(image_name, folder_path, grouped_obj)
image_name = pd.Series(grouped_train_df.groups.keys())

# %%
image_name.apply(save_data, args = (train_folder, grouped_train_df))
# Out:
# D:/Labelled/Data_1/image_0.jpg   D:/Labelled/Data_1/data/train\image_0.jpg
# D:/Labelled/Data_1/image_1.jpg   D:/Labelled/Data_1/data/train\image_1.jpg
# D:/Labelled/Data_1/image_100.jpg   D:/Labelled/Data_1/data/train\image_100.jpg
# D:/Labelled/Data_1/image_103.jpg   D:/Labelled/Data_1/data/train\image_103.jpg
# D:/Labelled/Data_1/image_104.jpg   D:/Labelled/Data_1/data/train\image_104.jpg
# D:/Labelled/Data_1/image_106.jpg   D:/Labelled/Data_1/data/train\image_106.jpg
# D:/Labelled/Data_1/image_108.jpg   D:/Labelled/Data_1/data/train\image_108.jpg
# D:/Labelled/Data_1/image_11.jpg   D:/Labelled/Data_1/data/train\image_11.jpg
# D:/Labelled/Data_1/image_113.jpg   D:/Labelled/Data_1/data/train\image_113.jpg
# D:/Labelled/Data_1/image_114.jpg   D:/Labelled/Data_1/data/train\image_114.jpg
# D:/Labelled/Data_1/image_116.jpg   D:/Labelled/Data_1/data/train\image_116.jpg
# D:/Labelled/Data_1/image_119.jpg   D:/Labelled/Data_1/data/train\image_119.jpg
# D:/Labelled/Data_1/image_12.jpg   D:/Labelled/Data_1/data/train\image_12.jpg
# D:/Labelled/Data_1/image_123.jpg   D:/Labelled/Data_1/data/train\image_123.jpg
# D:/Labelled/Data_1/image_124.jpg   D:/Labelled/Data_1/data/train\image_124.jpg
# D:/Labelled/Data_1/image_128.jpg   D:/Labelled/Data_1/data/train\image_128.jpg
# D:/Labelled/Data_1/image_13.jpg   D:/Labelled/Data_1/data/train\image_13.jpg
# D:/Labelled/Data_1/image_133.jpg   D:/Labelled/Data_1/data/train\image_133.jpg
# D:/Labelled/Data_1/image_134.jpg   D:/Labelled/Data_1/data/train\image_134.jpg
# D:/Labelled/Data_1/image_135.jpg   D:/Labelled/Data_1/data/train\image_135.jpg
# D:/Labelled/Data_1/image_136.jpg   D:/Labelled/Data_1/data/train\image_136.jpg
# D:/Labelled/Data_1/image_137.jpg   D:/Labelled/Data_1/data/train\image_137.jpg
# D:/Labelled/Data_1/image_138.jpg   D:/Labelled/Data_1/data/train\image_138.jpg
# D:/Labelled/Data_1/image_139.jpg   D:/Labelled/Data_1/data/train\image_139.jpg
# D:/Labelled/Data_1/image_14.jpg   D:/Labelled/Data_1/data/train\image_14.jpg
# D:/Labelled/Data_1/image_140.jpg   D:/Labelled/Data_1/data/train\image_140.jpg
# D:/Labelled/Data_1/image_141.jpg   D:/Labelled/Data_1/data/train\image_141.jpg
# D:/Labelled/Data_1/image_142.jpg   D:/Labelled/Data_1/data/train\image_142.jpg
# D:/Labelled/Data_1/image_144.jpg   D:/Labelled/Data_1/data/train\image_144.jpg
# D:/Labelled/Data_1/image_149.jpg   D:/Labelled/Data_1/data/train\image_149.jpg
# D:/Labelled/Data_1/image_150.jpg   D:/Labelled/Data_1/data/train\image_150.jpg
# D:/Labelled/Data_1/image_153.jpg   D:/Labelled/Data_1/data/train\image_153.jpg
# D:/Labelled/Data_1/image_154.jpg   D:/Labelled/Data_1/data/train\image_154.jpg
# D:/Labelled/Data_1/image_156.jpg   D:/Labelled/Data_1/data/train\image_156.jpg
# D:/Labelled/Data_1/image_157.jpg   D:/Labelled/Data_1/data/train\image_157.jpg
# D:/Labelled/Data_1/image_159.jpg   D:/Labelled/Data_1/data/train\image_159.jpg
# D:/Labelled/Data_1/image_160.jpg   D:/Labelled/Data_1/data/train\image_160.jpg
# D:/Labelled/Data_1/image_166.jpg   D:/Labelled/Data_1/data/train\image_166.jpg
# D:/Labelled/Data_1/image_167.jpg   D:/Labelled/Data_1/data/train\image_167.jpg
# D:/Labelled/Data_1/image_170.jpg   D:/Labelled/Data_1/data/train\image_170.jpg
# D:/Labelled/Data_1/image_171.jpg   D:/Labelled/Data_1/data/train\image_171.jpg
# D:/Labelled/Data_1/image_172.jpg   D:/Labelled/Data_1/data/train\image_172.jpg
# D:/Labelled/Data_1/image_174.jpg   D:/Labelled/Data_1/data/train\image_174.jpg
# D:/Labelled/Data_1/image_176.jpg   D:/Labelled/Data_1/data/train\image_176.jpg
# D:/Labelled/Data_1/image_184.jpg   D:/Labelled/Data_1/data/train\image_184.jpg
# D:/Labelled/Data_1/image_193.jpg   D:/Labelled/Data_1/data/train\image_193.jpg
# D:/Labelled/Data_1/image_195.jpg   D:/Labelled/Data_1/data/train\image_195.jpg
# D:/Labelled/Data_1/image_196.jpg   D:/Labelled/Data_1/data/train\image_196.jpg
# D:/Labelled/Data_1/image_197.jpg   D:/Labelled/Data_1/data/train\image_197.jpg
# D:/Labelled/Data_1/image_198.jpg   D:/Labelled/Data_1/data/train\image_198.jpg
# D:/Labelled/Data_1/image_2.jpg   D:/Labelled/Data_1/data/train\image_2.jpg
# D:/Labelled/Data_1/image_20.jpg   D:/Labelled/Data_1/data/train\image_20.jpg
# D:/Labelled/Data_1/image_200.jpg   D:/Labelled/Data_1/data/train\image_200.jpg
# D:/Labelled/Data_1/image_205.jpg   D:/Labelled/Data_1/data/train\image_205.jpg
# D:/Labelled/Data_1/image_207.jpg   D:/Labelled/Data_1/data/train\image_207.jpg
# D:/Labelled/Data_1/image_208.jpg   D:/Labelled/Data_1/data/train\image_208.jpg
# D:/Labelled/Data_1/image_211.jpg   D:/Labelled/Data_1/data/train\image_211.jpg
# D:/Labelled/Data_1/image_214.jpg   D:/Labelled/Data_1/data/train\image_214.jpg
# D:/Labelled/Data_1/image_215.jpg   D:/Labelled/Data_1/data/train\image_215.jpg
# D:/Labelled/Data_1/image_217.jpg   D:/Labelled/Data_1/data/train\image_217.jpg
# D:/Labelled/Data_1/image_218.jpg   D:/Labelled/Data_1/data/train\image_218.jpg
# D:/Labelled/Data_1/image_219.jpg   D:/Labelled/Data_1/data/train\image_219.jpg
# D:/Labelled/Data_1/image_220.jpg   D:/Labelled/Data_1/data/train\image_220.jpg
# D:/Labelled/Data_1/image_221.jpg   D:/Labelled/Data_1/data/train\image_221.jpg
# D:/Labelled/Data_1/image_225.jpg   D:/Labelled/Data_1/data/train\image_225.jpg
# D:/Labelled/Data_1/image_229.jpg   D:/Labelled/Data_1/data/train\image_229.jpg
# D:/Labelled/Data_1/image_235.jpg   D:/Labelled/Data_1/data/train\image_235.jpg
# D:/Labelled/Data_1/image_239.jpg   D:/Labelled/Data_1/data/train\image_239.jpg
# D:/Labelled/Data_1/image_240.jpg   D:/Labelled/Data_1/data/train\image_240.jpg
# D:/Labelled/Data_1/image_241.jpg   D:/Labelled/Data_1/data/train\image_241.jpg
# D:/Labelled/Data_1/image_244.jpg   D:/Labelled/Data_1/data/train\image_244.jpg
# D:/Labelled/Data_1/image_249.jpg   D:/Labelled/Data_1/data/train\image_249.jpg
# D:/Labelled/Data_1/image_256.jpg   D:/Labelled/Data_1/data/train\image_256.jpg
# D:/Labelled/Data_1/image_260.jpg   D:/Labelled/Data_1/data/train\image_260.jpg
# D:/Labelled/Data_1/image_268.jpg   D:/Labelled/Data_1/data/train\image_268.jpg
# D:/Labelled/Data_1/image_271.jpg   D:/Labelled/Data_1/data/train\image_271.jpg
# D:/Labelled/Data_1/image_274.jpg   D:/Labelled/Data_1/data/train\image_274.jpg
# D:/Labelled/Data_1/image_284.jpg   D:/Labelled/Data_1/data/train\image_284.jpg
# D:/Labelled/Data_1/image_299.jpg   D:/Labelled/Data_1/data/train\image_299.jpg
# D:/Labelled/Data_1/image_310.jpg   D:/Labelled/Data_1/data/train\image_310.jpg
# D:/Labelled/Data_1/image_317.jpg   D:/Labelled/Data_1/data/train\image_317.jpg
# D:/Labelled/Data_1/image_32.jpg   D:/Labelled/Data_1/data/train\image_32.jpg
# D:/Labelled/Data_1/image_323.jpg   D:/Labelled/Data_1/data/train\image_323.jpg
# D:/Labelled/Data_1/image_33.jpg   D:/Labelled/Data_1/data/train\image_33.jpg
# D:/Labelled/Data_1/image_332.jpg   D:/Labelled/Data_1/data/train\image_332.jpg
# D:/Labelled/Data_1/image_333.jpg   D:/Labelled/Data_1/data/train\image_333.jpg
# D:/Labelled/Data_1/image_34.jpg   D:/Labelled/Data_1/data/train\image_34.jpg
# D:/Labelled/Data_1/image_348.jpg   D:/Labelled/Data_1/data/train\image_348.jpg
# D:/Labelled/Data_1/image_35.jpg   D:/Labelled/Data_1/data/train\image_35.jpg
# D:/Labelled/Data_1/image_355.jpg   D:/Labelled/Data_1/data/train\image_355.jpg
# D:/Labelled/Data_1/image_356.jpg   D:/Labelled/Data_1/data/train\image_356.jpg
# D:/Labelled/Data_1/image_367.jpg   D:/Labelled/Data_1/data/train\image_367.jpg
# D:/Labelled/Data_1/image_369.jpg   D:/Labelled/Data_1/data/train\image_369.jpg
# D:/Labelled/Data_1/image_370.jpg   D:/Labelled/Data_1/data/train\image_370.jpg
# D:/Labelled/Data_1/image_371.jpg   D:/Labelled/Data_1/data/train\image_371.jpg
# D:/Labelled/Data_1/image_383.jpg   D:/Labelled/Data_1/data/train\image_383.jpg
# D:/Labelled/Data_1/image_385.jpg   D:/Labelled/Data_1/data/train\image_385.jpg
# D:/Labelled/Data_1/image_387.jpg   D:/Labelled/Data_1/data/train\image_387.jpg
# D:/Labelled/Data_1/image_389.jpg   D:/Labelled/Data_1/data/train\image_389.jpg
# D:/Labelled/Data_1/image_394.jpg   D:/Labelled/Data_1/data/train\image_394.jpg
# D:/Labelled/Data_1/image_396.jpg   D:/Labelled/Data_1/data/train\image_396.jpg
# D:/Labelled/Data_1/image_397.jpg   D:/Labelled/Data_1/data/train\image_397.jpg
# D:/Labelled/Data_1/image_398.jpg   D:/Labelled/Data_1/data/train\image_398.jpg
# D:/Labelled/Data_1/image_4.jpg   D:/Labelled/Data_1/data/train\image_4.jpg
# D:/Labelled/Data_1/image_400.jpg   D:/Labelled/Data_1/data/train\image_400.jpg
# D:/Labelled/Data_1/image_402.jpg   D:/Labelled/Data_1/data/train\image_402.jpg
# D:/Labelled/Data_1/image_403.jpg   D:/Labelled/Data_1/data/train\image_403.jpg
# D:/Labelled/Data_1/image_405.jpg   D:/Labelled/Data_1/data/train\image_405.jpg
# D:/Labelled/Data_1/image_406.jpg   D:/Labelled/Data_1/data/train\image_406.jpg
# D:/Labelled/Data_1/image_407.jpg   D:/Labelled/Data_1/data/train\image_407.jpg
# D:/Labelled/Data_1/image_409.jpg   D:/Labelled/Data_1/data/train\image_409.jpg
# D:/Labelled/Data_1/image_41.jpg   D:/Labelled/Data_1/data/train\image_41.jpg
# D:/Labelled/Data_1/image_410.jpg   D:/Labelled/Data_1/data/train\image_410.jpg
# D:/Labelled/Data_1/image_412.jpg   D:/Labelled/Data_1/data/train\image_412.jpg
# D:/Labelled/Data_1/image_43.jpg   D:/Labelled/Data_1/data/train\image_43.jpg
# D:/Labelled/Data_1/image_44.jpg   D:/Labelled/Data_1/data/train\image_44.jpg
# D:/Labelled/Data_1/image_46.jpg   D:/Labelled/Data_1/data/train\image_46.jpg
# D:/Labelled/Data_1/image_47.jpg   D:/Labelled/Data_1/data/train\image_47.jpg
# D:/Labelled/Data_1/image_48.jpg   D:/Labelled/Data_1/data/train\image_48.jpg
# D:/Labelled/Data_1/image_49.jpg   D:/Labelled/Data_1/data/train\image_49.jpg
# D:/Labelled/Data_1/image_50.jpg   D:/Labelled/Data_1/data/train\image_50.jpg
# D:/Labelled/Data_1/image_51.jpg   D:/Labelled/Data_1/data/train\image_51.jpg
# D:/Labelled/Data_1/image_52.jpg   D:/Labelled/Data_1/data/train\image_52.jpg
# D:/Labelled/Data_1/image_54.jpg   D:/Labelled/Data_1/data/train\image_54.jpg
# D:/Labelled/Data_1/image_55.jpg   D:/Labelled/Data_1/data/train\image_55.jpg
# D:/Labelled/Data_1/image_56.jpg   D:/Labelled/Data_1/data/train\image_56.jpg
# D:/Labelled/Data_1/image_57.jpg   D:/Labelled/Data_1/data/train\image_57.jpg
# D:/Labelled/Data_1/image_58.jpg   D:/Labelled/Data_1/data/train\image_58.jpg
# D:/Labelled/Data_1/image_59.jpg   D:/Labelled/Data_1/data/train\image_59.jpg
# D:/Labelled/Data_1/image_6.jpg   D:/Labelled/Data_1/data/train\image_6.jpg
# D:/Labelled/Data_1/image_60.jpg   D:/Labelled/Data_1/data/train\image_60.jpg
# D:/Labelled/Data_1/image_61.jpg   D:/Labelled/Data_1/data/train\image_61.jpg
# D:/Labelled/Data_1/image_62.jpg   D:/Labelled/Data_1/data/train\image_62.jpg
# D:/Labelled/Data_1/image_63.jpg   D:/Labelled/Data_1/data/train\image_63.jpg
# D:/Labelled/Data_1/image_66.jpg   D:/Labelled/Data_1/data/train\image_66.jpg
# D:/Labelled/Data_1/image_68.jpg   D:/Labelled/Data_1/data/train\image_68.jpg
# D:/Labelled/Data_1/image_69.jpg   D:/Labelled/Data_1/data/train\image_69.jpg
# D:/Labelled/Data_1/image_70.jpg   D:/Labelled/Data_1/data/train\image_70.jpg
# D:/Labelled/Data_1/image_72.jpg   D:/Labelled/Data_1/data/train\image_72.jpg
# D:/Labelled/Data_1/image_724.jpg   D:/Labelled/Data_1/data/train\image_724.jpg
# D:/Labelled/Data_1/image_725.jpg   D:/Labelled/Data_1/data/train\image_725.jpg
# D:/Labelled/Data_1/image_726.jpg   D:/Labelled/Data_1/data/train\image_726.jpg
# D:/Labelled/Data_1/image_728.jpg   D:/Labelled/Data_1/data/train\image_728.jpg
# D:/Labelled/Data_1/image_729.jpg   D:/Labelled/Data_1/data/train\image_729.jpg
# D:/Labelled/Data_1/image_73.jpg   D:/Labelled/Data_1/data/train\image_73.jpg
# D:/Labelled/Data_1/image_731.jpg   D:/Labelled/Data_1/data/train\image_731.jpg
# D:/Labelled/Data_1/image_732.jpg   D:/Labelled/Data_1/data/train\image_732.jpg
# D:/Labelled/Data_1/image_734.jpg   D:/Labelled/Data_1/data/train\image_734.jpg
# D:/Labelled/Data_1/image_736.jpg   D:/Labelled/Data_1/data/train\image_736.jpg
# D:/Labelled/Data_1/image_741.jpg   D:/Labelled/Data_1/data/train\image_741.jpg
# D:/Labelled/Data_1/image_744.jpg   D:/Labelled/Data_1/data/train\image_744.jpg
# D:/Labelled/Data_1/image_745.jpg   D:/Labelled/Data_1/data/train\image_745.jpg
# D:/Labelled/Data_1/image_749.jpg   D:/Labelled/Data_1/data/train\image_749.jpg
# D:/Labelled/Data_1/image_752.jpg   D:/Labelled/Data_1/data/train\image_752.jpg
# D:/Labelled/Data_1/image_753.jpg   D:/Labelled/Data_1/data/train\image_753.jpg
# D:/Labelled/Data_1/image_754.jpg   D:/Labelled/Data_1/data/train\image_754.jpg
# D:/Labelled/Data_1/image_755.jpg   D:/Labelled/Data_1/data/train\image_755.jpg
# D:/Labelled/Data_1/image_756.jpg   D:/Labelled/Data_1/data/train\image_756.jpg
# D:/Labelled/Data_1/image_757.jpg   D:/Labelled/Data_1/data/train\image_757.jpg
# D:/Labelled/Data_1/image_758.jpg   D:/Labelled/Data_1/data/train\image_758.jpg
# D:/Labelled/Data_1/image_759.jpg   D:/Labelled/Data_1/data/train\image_759.jpg
# D:/Labelled/Data_1/image_76.jpg   D:/Labelled/Data_1/data/train\image_76.jpg
# D:/Labelled/Data_1/image_760.jpg   D:/Labelled/Data_1/data/train\image_760.jpg
# D:/Labelled/Data_1/image_763.jpg   D:/Labelled/Data_1/data/train\image_763.jpg
# D:/Labelled/Data_1/image_764.jpg   D:/Labelled/Data_1/data/train\image_764.jpg
# D:/Labelled/Data_1/image_765.jpg   D:/Labelled/Data_1/data/train\image_765.jpg
# D:/Labelled/Data_1/image_769.jpg   D:/Labelled/Data_1/data/train\image_769.jpg
# D:/Labelled/Data_1/image_770.jpg   D:/Labelled/Data_1/data/train\image_770.jpg
# D:/Labelled/Data_1/image_771.jpg   D:/Labelled/Data_1/data/train\image_771.jpg
# D:/Labelled/Data_1/image_773.jpg   D:/Labelled/Data_1/data/train\image_773.jpg
# D:/Labelled/Data_1/image_777.jpg   D:/Labelled/Data_1/data/train\image_777.jpg
# D:/Labelled/Data_1/image_778.jpg   D:/Labelled/Data_1/data/train\image_778.jpg
# D:/Labelled/Data_1/image_779.jpg   D:/Labelled/Data_1/data/train\image_779.jpg
# D:/Labelled/Data_1/image_78.jpg   D:/Labelled/Data_1/data/train\image_78.jpg
# D:/Labelled/Data_1/image_781.jpg   D:/Labelled/Data_1/data/train\image_781.jpg
# D:/Labelled/Data_1/image_782.jpg   D:/Labelled/Data_1/data/train\image_782.jpg
# D:/Labelled/Data_1/image_783.jpg   D:/Labelled/Data_1/data/train\image_783.jpg
# D:/Labelled/Data_1/image_784.jpg   D:/Labelled/Data_1/data/train\image_784.jpg
# D:/Labelled/Data_1/image_786.jpg   D:/Labelled/Data_1/data/train\image_786.jpg
# D:/Labelled/Data_1/image_787.jpg   D:/Labelled/Data_1/data/train\image_787.jpg
# D:/Labelled/Data_1/image_788.jpg   D:/Labelled/Data_1/data/train\image_788.jpg
# D:/Labelled/Data_1/image_789.jpg   D:/Labelled/Data_1/data/train\image_789.jpg
# D:/Labelled/Data_1/image_79.jpg   D:/Labelled/Data_1/data/train\image_79.jpg
# D:/Labelled/Data_1/image_790.jpg   D:/Labelled/Data_1/data/train\image_790.jpg
# D:/Labelled/Data_1/image_791.jpg   D:/Labelled/Data_1/data/train\image_791.jpg
# D:/Labelled/Data_1/image_792.jpg   D:/Labelled/Data_1/data/train\image_792.jpg
# D:/Labelled/Data_1/image_794.jpg   D:/Labelled/Data_1/data/train\image_794.jpg
# D:/Labelled/Data_1/image_795.jpg   D:/Labelled/Data_1/data/train\image_795.jpg
# D:/Labelled/Data_1/image_80.jpg   D:/Labelled/Data_1/data/train\image_80.jpg
# D:/Labelled/Data_1/image_81.jpg   D:/Labelled/Data_1/data/train\image_81.jpg
# D:/Labelled/Data_1/image_82.jpg   D:/Labelled/Data_1/data/train\image_82.jpg
# D:/Labelled/Data_1/image_83.jpg   D:/Labelled/Data_1/data/train\image_83.jpg
# D:/Labelled/Data_1/image_85.jpg   D:/Labelled/Data_1/data/train\image_85.jpg
# D:/Labelled/Data_1/image_86.jpg   D:/Labelled/Data_1/data/train\image_86.jpg
# D:/Labelled/Data_1/image_87.jpg   D:/Labelled/Data_1/data/train\image_87.jpg
# D:/Labelled/Data_1/image_89.jpg   D:/Labelled/Data_1/data/train\image_89.jpg
# D:/Labelled/Data_1/image_90.jpg   D:/Labelled/Data_1/data/train\image_90.jpg
# D:/Labelled/Data_1/image_91.jpg   D:/Labelled/Data_1/data/train\image_91.jpg
# D:/Labelled/Data_1/image_94.jpg   D:/Labelled/Data_1/data/train\image_94.jpg
# D:/Labelled/Data_1/image_97.jpg   D:/Labelled/Data_1/data/train\image_97.jpg
# D:/Labelled/Data_1/image_99.jpg   D:/Labelled/Data_1/data/train\image_99.jpg
# 0      None
# 1      None
# 2      None
# 3      None
# 4      None
#        ...
# 196    None
# 197    None
# 198    None
# 199    None
# 200    None
# Length: 201, dtype: object

# %%
image_name = pd.Series(grouped_test_df.groups.keys())
image_name.apply(save_data, args = (test_folder, grouped_test_df))
# Out:
# D:/Labelled/Data_1/image_105.jpg   D:/Labelled/Data_1/data/test\image_105.jpg
# D:/Labelled/Data_1/image_118.jpg   D:/Labelled/Data_1/data/test\image_118.jpg
# D:/Labelled/Data_1/image_145.jpg   D:/Labelled/Data_1/data/test\image_145.jpg
# D:/Labelled/Data_1/image_15.jpg   D:/Labelled/Data_1/data/test\image_15.jpg
# D:/Labelled/Data_1/image_151.jpg   D:/Labelled/Data_1/data/test\image_151.jpg
# D:/Labelled/Data_1/image_158.jpg   D:/Labelled/Data_1/data/test\image_158.jpg
# D:/Labelled/Data_1/image_164.jpg   D:/Labelled/Data_1/data/test\image_164.jpg
# D:/Labelled/Data_1/image_186.jpg   D:/Labelled/Data_1/data/test\image_186.jpg
# D:/Labelled/Data_1/image_188.jpg   D:/Labelled/Data_1/data/test\image_188.jpg
# D:/Labelled/Data_1/image_19.jpg   D:/Labelled/Data_1/data/test\image_19.jpg
# D:/Labelled/Data_1/image_201.jpg   D:/Labelled/Data_1/data/test\image_201.jpg
# D:/Labelled/Data_1/image_202.jpg   D:/Labelled/Data_1/data/test\image_202.jpg
# D:/Labelled/Data_1/image_230.jpg   D:/Labelled/Data_1/data/test\image_230.jpg
# D:/Labelled/Data_1/image_231.jpg   D:/Labelled/Data_1/data/test\image_231.jpg
# D:/Labelled/Data_1/image_242.jpg   D:/Labelled/Data_1/data/test\image_242.jpg
# D:/Labelled/Data_1/image_250.jpg   D:/Labelled/Data_1/data/test\image_250.jpg
# D:/Labelled/Data_1/image_286.jpg   D:/Labelled/Data_1/data/test\image_286.jpg
# D:/Labelled/Data_1/image_325.jpg   D:/Labelled/Data_1/data/test\image_325.jpg
# D:/Labelled/Data_1/image_344.jpg   D:/Labelled/Data_1/data/test\image_344.jpg
# D:/Labelled/Data_1/image_36.jpg   D:/Labelled/Data_1/data/test\image_36.jpg
# D:/Labelled/Data_1/image_368.jpg   D:/Labelled/Data_1/data/test\image_368.jpg
# D:/Labelled/Data_1/image_39.jpg   D:/Labelled/Data_1/data/test\image_39.jpg
# D:/Labelled/Data_1/image_390.jpg   D:/Labelled/Data_1/data/test\image_390.jpg
# D:/Labelled/Data_1/image_391.jpg   D:/Labelled/Data_1/data/test\image_391.jpg
# D:/Labelled/Data_1/image_392.jpg   D:/Labelled/Data_1/data/test\image_392.jpg
# D:/Labelled/Data_1/image_393.jpg   D:/Labelled/Data_1/data/test\image_393.jpg
# D:/Labelled/Data_1/image_395.jpg   D:/Labelled/Data_1/data/test\image_395.jpg
# D:/Labelled/Data_1/image_404.jpg   D:/Labelled/Data_1/data/test\image_404.jpg
# D:/Labelled/Data_1/image_408.jpg   D:/Labelled/Data_1/data/test\image_408.jpg
# D:/Labelled/Data_1/image_411.jpg   D:/Labelled/Data_1/data/test\image_411.jpg
# D:/Labelled/Data_1/image_45.jpg   D:/Labelled/Data_1/data/test\image_45.jpg
# D:/Labelled/Data_1/image_53.jpg   D:/Labelled/Data_1/data/test\image_53.jpg
# D:/Labelled/Data_1/image_67.jpg   D:/Labelled/Data_1/data/test\image_67.jpg
# D:/Labelled/Data_1/image_71.jpg   D:/Labelled/Data_1/data/test\image_71.jpg
# D:/Labelled/Data_1/image_730.jpg   D:/Labelled/Data_1/data/test\image_730.jpg
# D:/Labelled/Data_1/image_733.jpg   D:/Labelled/Data_1/data/test\image_733.jpg
# D:/Labelled/Data_1/image_74.jpg   D:/Labelled/Data_1/data/test\image_74.jpg
# D:/Labelled/Data_1/image_743.jpg   D:/Labelled/Data_1/data/test\image_743.jpg
# D:/Labelled/Data_1/image_747.jpg   D:/Labelled/Data_1/data/test\image_747.jpg
# D:/Labelled/Data_1/image_761.jpg   D:/Labelled/Data_1/data/test\image_761.jpg
# D:/Labelled/Data_1/image_762.jpg   D:/Labelled/Data_1/data/test\image_762.jpg
# D:/Labelled/Data_1/image_77.jpg   D:/Labelled/Data_1/data/test\image_77.jpg
# D:/Labelled/Data_1/image_772.jpg   D:/Labelled/Data_1/data/test\image_772.jpg
# D:/Labelled/Data_1/image_774.jpg   D:/Labelled/Data_1/data/test\image_774.jpg
# D:/Labelled/Data_1/image_780.jpg   D:/Labelled/Data_1/data/test\image_780.jpg
# D:/Labelled/Data_1/image_785.jpg   D:/Labelled/Data_1/data/test\image_785.jpg
# D:/Labelled/Data_1/image_793.jpg   D:/Labelled/Data_1/data/test\image_793.jpg
# D:/Labelled/Data_1/image_84.jpg   D:/Labelled/Data_1/data/test\image_84.jpg
# D:/Labelled/Data_1/image_88.jpg   D:/Labelled/Data_1/data/test\image_88.jpg
# D:/Labelled/Data_1/image_9.jpg   D:/Labelled/Data_1/data/test\image_9.jpg
# 0     None
# 1     None
# 2     None
# 3     None
# 4     None
# 5     None
# 6     None
# 7     None
# 8     None
# 9     None
# 10    None
# 11    None
# 12    None
# 13    None
# 14    None
# 15    None
# 16    None
# 17    None
# 18    None
# 19    None
# 20    None
# 21    None
# 22    None
# 23    None
# 24    None
# 25    None
# 26    None
# 27    None
# 28    None
# 29    None
# 30    None
# 31    None
# 32    None
# 33    None
# 34    None
# 35    None
# 36    None
# 37    None
# 38    None
# 39    None
# 40    None
# 41    None
# 42    None
# 43    None
# 44    None
# 45    None
# 46    None
# 47    None
# 48    None
# 49    None
# dtype: object
